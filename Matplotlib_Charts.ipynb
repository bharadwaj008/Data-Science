# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df_scatter = pd.read_csv('mtcars.csv')
print(df_scatter)
#plotting scatter plot for mpg vs wt
plt.scatter(x=df_scatter['wt'],y=df_scatter['mpg'],c='cyan')
plt.title('car weight vs miles per gallon')
plt.xlabel('car weight')
plt.ylabel('miles per galloon')
plt.show()

#using line plot to draw scatter plot is easy as in place of fmt we can give only marker which only
#show points and not draw the lines between the points.
plt.plot(df_scatter['wt'],df_scatter['mpg'],'og')
plt.title(label='car weight vs miles per gallon',pad=12,fontdict=dict(family ='calibri',color='red',size=16))
plt.xlabel(xlabel='car weight')
plt.ylabel(ylabel='miles per gallon',labelpad=8,loc='bottom',rotation=90)
plt.show()
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %% [markdown]
# ## Line graph using matplotlib
# ->*Properties of Line Graphs*
#
# It is drawn using straight line segments between points. By joining all points, we get a resulting line that may be a straight line or a curve.
#
# It has two variables: one is independent while the other is dependent on the first independent variable.
#
# Ideally, the independent variable is exhibited on the horizontal axis, and the dependent variable is shown on the vertical axis.
#
# It can show the variation of one quantity with another, also known as variables.
#
# *Disadvantages of a Line Graph*
# Here are some of the major disadvantages of these graphs:
#
# ->If we plot too many lines on the same graph, it can become cluttered and hard to read.
#
# -> Application is limited to data sets that have numerical and whole values.
#
# ->When data sets have fractional or decimal values, it becomes difficult to plot it.
#
# *Advantages of a Line Graph*
#
# ->It helps to show small shifts that may be getting hard to spot in other graphs.
#
# ->It helps show trends for different periods.
#
# ->They are easy to understand.
#
# ->To compare data, more than one line can be plotted on the same axis.
#
# *How to Read a Line Graph*
#
# ->Find out what the two axes of the graph represent.
#
# Locate the data points on the graph.
#
# Draw a line that connects the plots to find out if there is any rise or drop in the trend. For multiple patterns, see if the lines are bisecting each other.
#
# *pyplot.plot() is used to plot the line graph*

# %%
# The plot() function is used to draw points (markers) in a diagram.

# By default, the plot() function draws a line from point to point.

# The function takes parameters for specifying points in the diagram.

# Parameter 1 is an array containing the points on the x-axis.

# Parameter 2 is an array containing the points on the y-axis.

#parammeter 1 and 2 x,y cannot be passed as key-word arguments

# If we need to plot a line from (1, 3) to (8, 10),
# we have to pass two arrays [1, 8] and [3, 10] to the plot function.

#Draw a line in a diagram from position (0,0) to position (6,250)
    
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

print('so here if we are just leaving with plt.plot() it will show the plotted graph along with address of it')
print('so here we can use plt.show() function to show only the plotted graph but not the address of it')
plt.plot(xpoints,ypoints)
plt.show() #comment this to see the address printing
# Out:
# so here if we are just leaving with plt.plot() it will show the plotted graph along with address of it
# so here we can use plt.show() function to show only the plotted graph but not the address of it

# %% [markdown]
# As we can see in the above output plot of line graph , there is no xlabel,ylabel,legend,title etc. So we will include them in the further cells.

# %%
#x values are optional and default to range(len(y)).
# %matplotlib inline
y=np.array([2,4,6,8])
x=np.array([1,2,3,4])
plt.plot(x,y)
plt.show()
print('''in the above plot we have given x values, we can also build a line graph without x values which
will default to range(len(y))[0,1,2....len(y)-1] it will use np.linspace(0,len(y)-1,n) 
here n is the number of points on y-axis displaying.''')
plt.plot(y)
plt.show()
# Out:
# in the above plot we have given x values, we can also build a line graph without x values which
# will default to range(len(y))[0,1,2....len(y)-1] it will use np.linspace(0,len(y)-1,n)
# here n is the number of points on y-axis displaying.

# %% [markdown]
# *plt.xlabel()* can be used to set label of x-axis and it can be given before plt.show()
#
# *plt.ylabel()* can be used to set label of y-axis and it can be given before plt.show()
#
# *plt.title()* can be used to set title of the graph and it can be given before plt.show()
#
# *label* argument in the plot() function can be used to give it as a legend.
#
# *plt.figure()* function is used to set the output plot size with *figsize* argument which is a tuple of two floats which indicates height and width of the output plot size and should use it at the top before start of the plot and first float number is width and second is height.
#
#
# A legend is a tool to help explain a graph. You are most commonly going to want to add one to a bar chart where you have several data series. You’ll also want to add one to a line or scatter plot when you have more than one series. Essentially you use a legend to help make a complicated plot more understandable.
#
# A Diagram Legend is an element that you can add to your diagram to provide information about the colors and/or line thicknesses and styles that have been used in the current diagram, where those colors and other styles have some particular meaning.

# %%
print('line graph with x label,y label,title and legend')
y=np.array([2,4,6,8])
x=np.array([1,2,3,4])
plt.figure(figsize=(10,5),dpi=200)
plt.plot(x,y,label='2x')
plt.xlabel(xlabel='x-axis')
plt.ylabel('y-axis',rotation=90)
plt.title('Plotting of line graph')
plt.legend()
plt.show()
# Out:
# line graph with x label,y label,title and legend

# %% [markdown]
# ## Set Font Properties for Title and Labels
#
# *You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.*

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'calibri','color':'blue','size':20}
font2 = {'family':'Times New Roman','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calories Burned", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Position the title,xlabel,ylabel
# *You can use the loc parameter in title(),xlabel(),ylabel() to position the title.*
#
# *Legal values for title() and xlabel() are: 'left', 'right', and 'center'. Default value is 'center'.*
# *Legal values for ylabel() are: 'bottom', 'center', and 'top'. Default value is 'center'.*
#
# ### title padding:
#
# 'pad':float, default: rcParams["axes.titlepad"] (default: 6.0)
# The offset of the title from the top of the Axes, in points.
#
# ### xlabel and ylabel padding:
# 'labelpad':float, default: rcParams["axes.labelpad"] (default: 4.0)
# Spacing in points from the Axes bounding box including ticks and tick labels. If None, the previous value is left as is.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'calibri','color':'blue','size':20}
font2 = {'family':'Times New Roman','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1,loc='left',pad=20)
plt.xlabel("Average Pulse", fontdict = font2,loc='left')
plt.ylabel("Calorie Burnage", fontdict = font2,loc='bottom',labelpad=15)

plt.plot(x, y)
plt.show()

# %% [markdown]
# As we have seen above the plot using same blue line to join the every two points and there is no marker
# for each point. We can edit that using 'fmt'.
#
# A format string consists of a part for color, marker and line:
#
# fmt = '[marker][line][color]'(This argument cannot be passed as keyword.)(mlc shortcut to remember)
#
# marker means the pointer style, line means the line style and color means line,marker face color and
# marker edge color.
#
# The default format string is 'b-', which is a solid blue line
#
# Line Syntax	Description
#
# '-'	        Solid line
# ':'	        Dotted line
# '--'	    Dashed line
# '-.'	    Dashed/dotted line
# ''          No line
#
# The short color value can be one of the following:
#
# Color Reference:
# Color Syntax	Description
#
# 'r'	Red
# 'g'	Green
# 'b'	Blue
# 'c'	Cyan
# 'm'	Magenta
# 'y'	Yellow
# 'k'	Black
# 'w'	White
#
# marker reference:https://www.w3schools.com/python/matplotlib_markers.asp
#
# Marker	Description
# 'o'	Circle
# '*'	Star
# '.'	Point
# ','	Pixel
# 'x'	X
# 'X'	X (filled)
# '+'	Plus
# 'P'	Plus (filled)
# 's'	Square
# 'D'	Diamond
# 'd'	Diamond (thin)
# 'p'	Pentagon
# 'H'	Hexagon
# 'h'	Hexagon
# 'v'	Triangle Down
# '^'	Triangle Up
# '<'	Triangle Left
# '>'	Triangle Right
# '1'	Tri Down
# '2'	Tri Up
# '3'	Tri Left
# '4'	Tri Right
# '|'	Vline
# '_'	Hline

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o--c')
plt.show()

# %% [markdown]
# ## text
# matplotlib.pyplot.text(x, y, s, fontdict=None, **kwargs)
#
# Add text to the Axes.
#
# Add the text s to the Axes at location x, y in data coordinates.
#
# Parameters:
#
# 'x', 'y':float
# The position to place the text. By default, this is in data coordinates. The coordinate system can be changed using the transform parameter.
#
# 's':str
# The text.
#
# 'fontdict': dict, default: None
# A dictionary to override the default text properties. If fontdict is None, the defaults are determined by rcParams.
#
# Returns: Text
# The created Text instance.
#
# *You can put a rectangular box around the text instance (e.g., to set a background color) by using the keyword bbox. bbox is a dictionary of Rectangle properties.*

# %%
y = np.array([2,8,12,18,21])
plt.figure(figsize=(7,5))
plt.plot(y,label='Y')
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS',loc='bottom')
plt.title('Graph of Y',loc='center')
plt.legend()
#here comes the hero
plt.figtext(0.5,0.7,'This is text in the graph')
plt.show()

# %%
y = np.array([2,8,12,18,21])
plt.figure(figsize=(7,5))
plt.plot(y,label='Y')
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS',loc='bottom')
plt.title('Graph of Y',loc='center')
plt.legend()
#here comes the hero
plt.text(x=3,y=15 ,s='This is text in the graph in the box', 
bbox=dict(facecolor='yellow',edgecolor='black',alpha=0.7),
fontdict = {'family':'Times New Roman','color':'darkred','size':15})
#alpha in bbox indicates the transparency of background color 
# the lower the alpha is the higher the transparency
plt.show()

# %% [markdown]
# ## Plotting multiple sets of data
#
# ->There are various ways to plot multiple sets of data.
#
# 1.The most straight forward way is just to call plot multiple times.
#
# ex:
# plot(x1, y1, 'bo')
# plot(x2, y2, 'go')
#
# 2.If x and/or y are 2D arrays a separate data set will be drawn for every column. If both x and y are 2D, they must have the same shape. If only one of them is 2D with shape (N, m) the other must have length N and will be used for every data set m.
#
# Example:x = [1, 2, 3]
# y = np.array([[1, 2], [3, 4], [5, 6]])
#
# 3.The third way is to specify multiple sets of [x], y, [fmt] groups:
#
# ex:plot(x1, y1, 'g^', x2, y2, 'g-')
#
# ##### In this case, any additional keyword argument applies to all datasets. Also, this syntax cannot be combined with the data parameter.

# %% [markdown]
# ## Plotting multiple lines in line plot using 2d array

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = np.array([[1, 2], [3, 4], [5, 6]])
print(y.shape)
line1,line2 =plt.plot(x,y,label='2 lines plot')#this 2 lines plot label will apply to all lines in the plot
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Plot of multiple lines using 2d array') 
plt.legend([line1,line2],['2d1','2d2'])#line1,line2 now got labels 2d1,2d2 got changed from 2 lines plot
plt.show()
# so here as u can see the plotted chart we can't specify the label for each in plot function but we can 
#specify it in the legend function when we plot the graph using 2d arrays.
# Out:
# (3, 2)

# %% [markdown]
# ### Plotting multiple lines in line plot using the most straight forward way is just to call plot multiple times.

# %%
y1 = np.arange(0,10,0.5)
y2 = np.arange(5,15,0.5)
plt.figure(figsize=(8,5))
l1,=plt.plot(y1,'o--c',label='y1')
l2,=plt.plot(y2,'^-b',label='y2')
plt.title('Plotting multiple lines using multiple calls of plot function')
plt.xlabel('x-values',fontdict={'family':'calibri','size':20,'color':'red'})
plt.ylabel('y-values',loc='top',labelpad=20)
plt.legend()
plt.show()

# %% [markdown]
# #### Plotting multiple lines in line plot using specifying of  multiple sets of [x], y, [fmt] groups:

# %%
y1 = np.arange(0,10,0.5)
y2 = np.arange(3,15,0.5)
plt.plot(y1,'o-r',y2,'.:c')
plt.show()

# %% [markdown]
# *matplotlib.pyplot.legend(*args, **kwargs)*
#
# -> used to place a legend on the Axes.
#
# Call signatures:
# legend()
# legend(handles, labels)
# legend(handles=handles)
# legend(labels)
#
# *The call signatures correspond to the following different ways to use this method:*
#
# 1.Automatic detection of elements to be shown in the legend
#
# The elements to be added to the legend are automatically determined, when you do not pass in any extra arguments.
#
# In this case, the labels are taken from the artist. You can specify them either at artist creation or by calling the set_label() method on the artist:
#
# ex:
# ax.plot([1, 2, 3], label='Inline label')
#
# ax.legend()
#
# or:
#
# line, = ax.plot([1, 2, 3])
#
# line.set_label('Label via method')
#
# ax.legend()
#
# **Specific artists can be excluded from the automatic legend element selection by using a label starting with an underscore, "_".**
#
# 2.Explicitly listing the artists and labels in the legend
#
# For full control of which artists have a legend entry, it is possible to pass an iterable of legend artists followed by an iterable of legend labels respectively:
#
# ex: ax.legend([line1, line2, line3], ['label1', 'label2', 'label3'])
#
# 3.Explicitly listing the artists in the legend
#
# This is similar to 2, but the labels are taken from the artists' label properties.
#
# Example:
#
# line1, = ax.plot([1, 2, 3], label='label1')
#
# line2, = ax.plot([1, 2, 3], label='label2')
#
# ax.legend(handles=[line1, line2])
#
# -> 3 is used just to change the legend order of display
#
# **Parameters**:
# 'handles': sequence of Artist, optional
# A list of Artists (lines, patches) to be added to the legend. Use this together with labels, if you need full control on what is shown in the legend and the automatic mechanism described above is not sufficient.
#
# **The length of handles and labels should be the same in this case. If they are not, they are truncated to the smaller length.**
#
# 'labels':list of str, optional
# A list of labels to show next to the artists. Use this together with handles, if you need full control on what is shown in the legend and the automatic mechanism described above is not sufficient.
#
# Returns: Legend
#
# for remaining parameters refer to https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %%
#method 1
plt.figure(figsize= (5,3))
plt.plot([1, 2, 3], label='Inline label')
plt.legend()
plt.show()

plt.figure(figsize=(5,3))
line, = plt.plot([1, 2, 3])
line.set_label('Label via method')
plt.legend()
plt.show()

# %%
#method2
y1 = np.arange(2,12,0.4)
y2 = np.arange(3,14,0.5)
# plt.figure(figsize=(12,7))
l1,l2 = plt.plot(y1,'^-g',y2,'o:c')
plt.legend([l1,l2],['line1','line2'])
plt.title('legend specifying using explicitly listing the labels and handles',pad=15,loc='right')
plt.show()

# %%
# 3rd method similar to 2nd method but I think it has no use as specify labels in the 
#funtion itself and use legend() funtion to Change the order of the labels and order of the lines display
#and can exclude without using _ at starting of the name for label
x = np.linspace(3,12,10)
y = np.linspace(5,17,10)
line1, = plt.plot(x,'o--c',label='line1')
line2, = plt.plot(y,'^:m',label='line2')
plt.legend(handles=[line2])
fontdict={'family':'TimesNewRoman','color':'blue','size':'16'}
plt.xlabel(xlabel='x-axis',labelpad=8,fontdict=fontdict,loc='right')
plt.ylabel(ylabel='y-axis')
plt.title(label='Linspace Graph',pad=10)
plt.text(x=5,y=10,s='text',bbox=dict(facecolor='cyan',edgecolor='black',alpha=0.3),fontdict=fontdict)
plt.show()
# Out:
# findfont: Font family 'TimesNewRoman' not found.
# findfont: Font family 'TimesNewRoman' not found.
# findfont: Font family 'TimesNewRoman' not found.
# findfont: Font family 'TimesNewRoman' not found.
# findfont: Font family 'TimesNewRoman' not found.
# findfont: Font family 'TimesNewRoman' not found.
# findfont: Font family 'TimesNewRoman' not found.
# findfont: Font family 'TimesNewRoman' not found.

# %% [markdown]
# ## xticks() and same applies to the yticks() function
# Calling this function with no arguments (e.g. xticks()) is the pyplot equivalent of calling get_xticks
# and get_xticklabels on the current axes. Calling this function with arguments is the pyplot equivalent
# of calling set_xticks and set_xticklabels on the current axes.
#
# Parameters
# :
# *ticks*:
# array-like, optional
# The list of xtick locations. Passing an empty list removes all xticks.
#
# *labels*:
# array-like, optional
# The labels to place at the given ticks locations. This argument can only be passed if ticks is passed as well.
#
# *minor*:
# bool, default: False
# If False, get/set the major ticks/labels; if True, the minor ticks/labels.
#
# **kwargs
# Text properties can be used to control the appearance of the labels.
#
# Returns:
#
# locs:The list of xtick locations.
#
# labels:The list of xlabel Text objects.
#
# rotation: float or {'vertical', 'horizontal'}(rotates in anti-Clock wise direction)

# %%
# plt.minorticks_on()#makes minor minor ticks visible between major ticks on both the axes
y= np.linspace(5,10,10)
plt.plot(y,'o')
locs, labels = plt.xticks()  # Get the current locations and labels.
print('before using ticks method: \n',locs,labels,'\n')
plt.xticks(ticks=[0, 2 ,4 ,8])
#giving only locations of x-axis point to ticks argument
#giving only ticks arguent akes ticks used as ticks and labels
locs, labels = plt.xticks()  # Get the current locations and labels.
print('after using ticks Method: \n',locs,labels)
plt.show()
# Out:
# before using ticks method:
#  [-2.  0.  2.  4.  6.  8. 10.] [Text(-2.0, 0, '−2'), Text(0.0, 0, '0'), Text(2.0, 0, '2'), Text(4.0, 0, '4'), Text(6.0, 0, '6'), Text(8.0, 0, '8'), Text(10.0, 0, '10')]
#
# after using ticks Method:
#  [0 2 4 8] [Text(0, 0, '0'), Text(2, 0, '2'), Text(4, 0, '4'), Text(8, 0, '8')]

# %%
 #using both ticks and labels arguments which
#will print labels in positions given in ticks argument and using rotation parameter will rotate the ticks
#by x degrees in anti-clockwise direction
plt.plot(np.linspace(0,5,5))
plt.xticks([0, 1, 2], ['January', 'February', 'March'],rotation=90)  # Set text labels and properties 
#this roation is a Text property and can be used for all xticks,yticks,xlabel,ylabel,title.
# plt.xticks([])  # Disable xticks.
locs, labels = plt.xticks()  # Get the current locations and labels.
print(locs,labels)
plt.show()
# Out:
# [0 1 2] [Text(0, 0, 'January'), Text(1, 0, 'February'), Text(2, 0, 'March')]

# %% [markdown]
# annotate,markeredgecolor,markerfacecolor,linestyle,color,slicing
#
# plt.savefig() -> to save the plotted figure
#
# plt.bar()-> to display the bar chart
# bars[0,1,...].set_hatch() -> setting style of each bar in the bar plot

# %% [markdown]
# ## matplotlib.pyplot.axis
# -> Used to set the axes limits of both x and y axes
# Parameters:
# xmin, xmax, ymin, ymax:float, optional
#
# The axis limits to be set. This can also be achieved using
#
# ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))

# %%
line1, =plt.plot(np.linspace(1,7,10),'^--m')
plt.axis([-1,10,-2,14])#here 1st is xmin,2nd is xmax and 3rd is ymin and 4th is ymax
plt.show()

# %% [markdown]
# ### matplotlib.lines.Line2D some imp properties :
#
# markeredgecolor or mec : color
#
# markeredgewidth or mew : float
#
# markerfacecolor or mfc : color
#
# markerfacecoloralt or mfcalt : color
#
# markersize or ms : float
#
# linestyle or ls : {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#
# linewidth or lw : float
#
# color='green', marker='o', linestyle='dashed' is same as 'o--g'[mlc]
#
# fmt vs kwargs:When conflicting with fmt, keyword arguments take precedence.

# %%
line1,= plt.plot(np.linspace(2,17,10),'<:c')
print('default marker size: ',line1.get_ms())
#we can get markersize of the line using get_markersize() or get_ms() method.
line1.set_ms(10)#we an set markersize of the line using set_markersize() or set_ms() methods with float input.
plt.title('Setting nd Getting Marker size(ms)',pad=10)
plt.show()
# Out:
# default marker size:  6.0

# %%
#line style
line1,= plt.plot(np.linspace(2,17,10))
print('default line style: ',line1.get_ls())
#we can get markersize of the line using get_markersize() or get_ms() method.
line1.set_ls('--')#we an set markersize of the line using set_markersize() or set_ms() methods with float input.
plt.title('Setting nd Getting line style(ls)',pad=10,fontdict=dict(color='red',family='calibri',size=22))
plt.show()
# Out:
# default line style:  -

# %%
line, = plt.plot(np.linspace(2,18,12),'>-.b',label='line width')
plt.legend()
plt.title(label='Setting nd Getting line width',pad=15,fontdict=dict(color='cyan',size=21))
print('default line width: ',line.get_lw())#we can use set_lw() or set_linewidth() 
#method to set the line width with float input
line.set_lw(2)#we can use set_lw() or set_linewidth() method to set the line width
plt.show()
# Out:
# default line width:  1.5

# %%
#markerfacecolor 
line1,= plt.plot(np.linspace(2,17,10),'*-')
print('default marker face color ',line1.get_mfc())
#we can use set_mfc() or set_markerfacecolor() 
#method to set the marker face color with color input
plt.title('Setting nd Getting marker face color(mfc)',pad=10,fontdict=dict(color='red',family='calibri',size=22))
line1.set_ms(10)#setting markersize to 10 to see marker clearly
line1.set_mfc('red')
plt.show()
# Out:
# default marker face color  #1f77b4

# %% [markdown]
# ## Bar graph (bar and barh)
# some parameters to be noted:
#
# 'color':color or list of color, optional
#
# ->The colors of the bar faces.
#
# 'edgecolor':color or list of color, optional
#
# ->The colors of the bar edges.
#
# 'linewidth':float or array-like, optional
#
# ->Width of the bar edge(s). If 0, don't draw edges.
#
# 'tick_label':str or list of str, optional
#
# ->The tick labels of the bars. Default: None (Use default numeric labels.)
#
# 'label':str or list of str, optional
# A single label is attached to the resulting BarContainer as a label for the whole dataset. If a list is provided, it must be the same length as x and labels the individual bars. Repeated labels are not de-duplicated and will cause repeated label entries, so this is best used when bars also differ in style (e.g., by passing a list to color.)
#
# 'edgecolor':color or list of color, optional
#
# ->The colors of the bar edges.

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
bars = plt.bar(x,y,label=x,ec='lightblue',color='darkviolet',lw=3)
#fc sets the color of patch face color and ec sets the patch edge color
patterns= ['|','o','.','*']
labels= ['a','b','c','d']
for bar in bars:
    bar.set_hatch(patterns.pop())

    
plt.legend()    
plt.show()
plt.barh(x,y)
plt.show()

#hatch sytles:
#https://matplotlib.org/stable/gallery/shapes_and_collections/hatch_style_reference.html

# %% [markdown]
# ## plt.subplots() in w3schools
# histogram,pie chart,box and whiskers plot
#
# ### With the subplot() function you can draw multiple plots in one figure:
#
# -> The subplot() function takes three arguments that describes the layout of the figure.
#
# -> The layout is organized in rows and columns, which are represented by the first and second argument.
#
# -> The third argument represents the index of the current plot.

# %%
y = np.linspace(13,18,10)
y1 = np.linspace(10,20,9)

plt.figure(figsize=(10,7))#pltfigure() should be given before the pltsubplot()

plt.subplot(2,1,1)
plt.title('suplot1')
plt.suptitle('super title of all subplots')#plt.suptitle() should be used with in subplot first figure
plt.xlabel('x-label1',labelpad=12,fontdict=dict(family='Times new roman',size=20,color='cyan'))
plt.ylabel('y-label1')
plt.plot(y,'X-k',label='subplot1')
plt.legend()
plt.text(y=15,x=2,s='text in s1')
plt.xticks(ticks=[1,2,5,7,8],rotation=90)


plt.figure(figsize=(9,6))
plt.subplot(2,1,2)
plt.plot(y1,'+:r')
plt.title('subplot2')
plt.xlabel('xlabel2')
plt.ylabel('ylabel2')

plt.show()

# %% [markdown]
# ## line plot and bar chart using gas prices data from keith galli video

# %%
gas_data = pd.read_csv('gas_prices.csv')
#line plot of comparing gas prices of uk , us , canada across 1990-2008
line1,=plt.plot(gas_data['Year'],gas_data['USA'],ls=':',marker='X',ms=7,color='red')
line2, = plt.plot(gas_data['Year'],gas_data['UK'],'o--b'
,lw=2,mfc='green',ms=8)
line3, = plt.plot(gas_data['Year'],gas_data['Canada'],'*--c')
plt.title('Gas Prices Comparision of UK,USA and Canada')
plt.xlabel('Year')
plt.ylabel('Prices in USD',fontdict=dict(family = 'Times new roman',size=18,color='black'))
plt.legend(handles=[line1,line2,line3], labels=['USA','UK','Canada'])
plt.xticks(ticks=gas_data.Year[::2])
plt.show()
list1=gas_data.loc[gas_data['Year']==2008][['USA','UK','Canada']].values.reshape(3)
gas_data
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %% [markdown]
# ## bar() function takes arguments that describes the layout of the bars.
#
# ->The categories and their values represented by the first and second argument as arrays.
#
# *linewidth(lw)*:float or array-like, optional
# Width of the bar edge(s). If 0, don't draw edges.
#
# *color*: color or list of color, optional
# The colors of the bar faces.
#
# *width*:float or array-like, default: 0.8
# The width(s) of the bars.
#
# *set_ec(color)*: Alias for set_edgecolor.
#
# set_edgecolor(color)
# Set the patch edge color.
#
# set_facecolor(color)
# Set the patch face color.
#
# set_fc(): Alias for set_facecolor.
#
# *Note: For horizontal bars, use height instead of width.*

# %%
#barh of US,UK and Canada across 2008
list1= gas_data.loc[gas_data['Year']==2008][['USA','UK','Canada']].values.reshape(3)
print(list1)
labels= ['USA','UK','Canada']
bars = plt.bar(x=['USA','UK','Canada'],height=list1,ec='yellow',lw=3,width=0.5,label=labels,hatch=patterns)#ec - edge color changes the color of hatch(pattern)
#edge in each bar and fc - face color changes the color the bar.
patterns=['+','o','*']
#we can either use bar.set_hatch() to set the hatch of the each bar or can give the list to hatch parameter
#in the bar function, the same goes with set_label() we can the labels we want in the same order to
#the label parameter

# for bar in bars:
#     bar.set_hatch(patterns.pop(0))#set_hatch pattern is used to set the hatch of each bar
#     bar.set_label(labels.pop(0))
plt.legend(title='countries')
plt.ylabel(ylabel='Prices in USD',labelpad=10)
plt.title(label='Gas Prices of US,UK,Canada in 2008',pad=12,loc='left',bbox=dict(fc='cyan',ec='black',alpha=0.5))
plt.savefig('bar_chart1.png',dpi=200)#use plt.savefig() function to save the chart created nd 
#can adjust resolution using dpi and we have to save it before showing it to the output
plt.show()
# Out:
# [3.27 7.42 4.08]

# %% [markdown]
# ## Pie Chart
#
# ->As you can see the pie chart draws one piece (called a wedge) for each value in the array (in this case [35, 25, 25, 15]).
#
# ->The size of each wedge is determined by comparing the value with all the other values, by using this formula:
#
# The value divided by the sum of all values: x/sum(x)
#
# ->We can add labels to the pie chart with the labels parameter.
#
# ->The *labels* parameter must be an array with one label for each wedge
#
# ->'autopct':None or str or callable, default: None
# If not None, autopct is a string or function used to label the wedges with their numeric value. The label will be placed inside the wedge. If autopct is a format string, the label will be fmt % pct. If autopct is a function, then it will be called.
# https://stackoverflow.com/questions/6170246/how-do-i-use-matplotlib-autopct
#
# ->'shadow':bool, default: False
#
# Draw a shadow beneath the pie.
#
# ->'startangle':float, default: 0 degrees
#
# The angle by which the start of the pie is rotated, counterclockwise from the x-axis.
#
# By default the plotting of the first wedge starts from the x-axis and moves counterclockwise

# %%
#Hyundai,Maruti,Honda,Tata,Toyota,Datsun,Chevorlet,Skoda
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df_cars = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')
fuel_type_counts=df_cars['fuel'].value_counts()
mylabel=['Diesel','Petrol','CNG','LPG','Electric']
plt.pie(fuel_type_counts,labels=mylabel,explode=[0,0,0.9,0.9,0.9])
plt.show()

# %%
## car company wise division pie chart
import re
list_companies=[]
labels= ['skoda','maruti','honda','tata','toyota','hyundai']
for company in labels:
    df_com= df_cars.loc[df_cars['name'].str.contains(pat=rf'{company}',regex=True,flags=re.I)]
    list_companies.append(len(df_com))
list_companies= np.array(list_companies)
#here we are using autopct paarmeter to dispay the percentage of each wedge and also the value of 
#each wedge.
#autopct enables you to display the percent value using Python string formatting. 
#For example, if autopct='%.2f', then for each pie wedge, the format string is '%.2f' 
#and the numerical percent value for that wedge is pct, so the wedge label is set to the string '%.2f'%pct.

#if we want to display the percentage along with the value we can do that by using a function (labda is)
#easier option as matplotlib itself is providing the pct value for each wedge which means percentage
#value of each wedge, fromm that we can calculate the value of each wedge.

plt.figure(figsize=(20,10))#figsize first argument is width and next is height.
plt.subplot(2,1,1)
plt.pie(list_companies,labels=labels,autopct=lambda p: f'{p:.0f}% ({(p*np.sum(list_companies))//100:.0f})')
plt.title(label='car company wise division',pad=12,fontdict=dict(color='green',size='20',
fontfamily='times new roman'))
plt.figure(figsize=(30,10))
plt.subplot(2,1,2)
plt.pie(list_companies,labels=labels,autopct=lambda p: f'{p:.0f}% ({(p*np.sum(list_companies))//100:.0f})')
plt.title(label='car company wise division with only per',pad=12,fontdict=dict(color='Magenta',size='20',
fontfamily='times new roman'))
plt.show()

# %% [markdown]
# plt.sytle.use('ggplot')#good to see colors using by this style
# ## Histogram:
#
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.
#
# plot histogram of selling_price and km_driven
#
# 'x': (n,) array or sequence of (n,) arrays
#
# ->Input values, this takes either a single array or a sequence of arrays which are not required to be of the same length.
#
# 'bins':int or sequence or str, default: rcParams["hist.bins"] (default: 10)
#
# ->If bins is an integer, it defines the number of equal-width bins in the range.
#
# ->If bins is a sequence, it defines the bin edges, including the left edge of the first bin and the right edge of the last bin; in this case, bins may be unequally spaced. All but the last (righthand-most) bin is half-open. In other words, if bins is:
#
# [1, 2, 3, 4]
# then the first bin is [1, 2) (including 1, but excluding 2) and the second [2, 3). The last bin, however, is [3, 4], which includes 4.
#
# If bins is a string, it is one of the binning strategies supported by numpy.histogram_bin_edges: 'auto', 'fd', 'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'.
#
# 'range':tuple or None, default: None
#
# ->The lower and upper range of the bins. Lower and upper outliers are ignored. If not provided, range is (x.min(), x.max()). Range has no effect if bins is a sequence.
#
# ->If bins is a sequence or range is specified, autoscaling is based on the specified bin range instead of the range of x.
#
# 'align':{'left', 'mid', 'right'}, default: 'mid'
# The horizontal alignment of the histogram bars.
#
# 'left': bars are centered on the left bin edges.
#
# 'mid': bars are centered between the bin edges.
#
# 'right': bars are centered on the right bin edges.
#
# 'orientation':{'vertical', 'horizontal'}, default: 'vertical'
# If 'horizontal', barh will be used for bar-type histograms and the bottom kwarg will be the left edges.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.minorticks_on()
df_cars = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')
plt.hist(df_cars['selling_price'],bins=4,fc='skyblue',ec='lightgreen',lw=6)
plt.title('price distribution of all owner type cars',pad=12)
plt.show()
#conclusion from this histogram is between 0 to 2.1 lacs most of the cars have their price.(this is for
#all types of owners) but if we want to see for different types of owners . first owner and second owner.
st_owner_sp = df_cars.loc[df_cars['owner'].isin(['Third Owner','Second Owner']),'selling_price']
plt.minorticks_on()
plt.hist(st_owner_sp,bins=4,fc='pink',ec='red',lw=3)
plt.xticks(ticks=[0,1*(1e6),2*(1e6),3*(1e6),4*(1e6),5*(1e6),6*(1e6),7*(1e6),8*(1e6)],
labels=['0 lacs','1 lac','2 lacs','3 lacs','4 lacs','5 lacs','6 lacs', '7 lacs','8 lacs'])
plt.title('price distribution of second and third owner cars',pad=14)
plt.show()

# %%
#km_driven histogram
plt.minorticks_on()#highly useful for the histograms or any other charts to identify middle interval between
#two major ticks.
plt.hist(df_cars['km_driven'],ec='white')
plt.xticks([0,1_00_000,200000,300000])
plt.title(label='No. of kms driven by the second hand cars',pad=14,bbox=dict(fc='red',ec='black',alpha=0.5))
plt.xlabel(xlabel='No.of kms',labelpad=10,loc='left',fontdict=dict(fontfamily='times new roman',size=15,color='Magenta'))
plt.ylabel(ylabel='No.of cars',labelpad=10)
plt.show()
#conlusion: between 0 to 80000 km driven there are 3100 cars.

# %% [markdown]
# ## boxer plot
# ->A box and whisker plot is defined as a graphical method of displaying variation in a set of data. In most cases, a histogram analysis provides a sufficient display, but a box and whisker plot can provide additional detail while allowing multiple sets of data to be displayed in the same graph.
# https://www.statology.org/remove-outliers-python/
# https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/box-whisker-plots/a/box-plot-review
#
# *Elements of a Box and Whisker Plot*
#
# The elements required to construct a box and whisker plot outliers are given below.
#
# 1.Minimum value (Q0 or 0th percentile) = Q1 - 1.5*(IQR)
#
# 2.First quartile (Q1 or 25th percentile)
#
# 3.Median (Q2 or 50th percentile)
#
# 4.Third quartile (Q3 or 75th percentile)
#
# 5.Maximum value (Q4 or 100th percentile)= Q3 + 1.5*(IQR)
#
# 6.Interquartile range = Q3 - Q1
#
# -> Although you can have "many" outliers (in a large data set), it is impossible for "most" of the data points to be outside of the IQR. The IQR, or more specifically, the zone between Q1 and Q3, by definition contains the middle 50% of the data. Extending that to 1.5*IQR above and below it is a very generous zone to encompass most of the data.

# %%
## box and whisker's plot between price of hyundai and maruthi cars and also km_driven by hyundai and
## maruti cars.
import re
companies = ['maruti','hyundai','tata']
box_list_price=[]
for company in companies:
    df_com = df_cars.loc[df_cars['name'].str.contains(regex=True,pat=rf'{company}',flags=re.I)]['selling_price']
    box_list_price.append(df_com)
plt.figure(figsize=(8,10))
plt.title('selling price of hyundai and maruti companies comparision')
plt.boxplot(box_list_price,labels=['maruti','hyundai','tata'],showmeans=True,
            flierprops=dict(marker='*',color='yellow',ms=7),boxprops=dict(c='lightblue',lw=3,gapcolor='yellow'))
#showmeans is used to show the mean in the box plot
#flierprops is used to set the flier(outliers) properties.
#boxprops is used to set the box properties which are q1 and q3.
plt.show()

# %% [markdown]
# ## Side - side by bar chart from frequency table

# %%
# making a frequency table of gear and carb
crosstab = pd.crosstab(index=df_scatter['gear'],columns=df_scatter['cyl'])
print(f"freqeuncy distribution of gears with respect to no.of cylinders:\n{crosstab}")
print(crosstab.index,crosstab.columns,crosstab.loc[3].to_numpy().reshape(3))
# Out:
# freqeuncy distribution of gears with respect to no.of cylinders:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2
# Int64Index([3, 4, 5], dtype='int64', name='gear') Int64Index([4, 6, 8], dtype='int64', name='cyl') [ 1  2 12]

# %% [markdown]
# we can draw the side-by-side bar chart in 2 ways .
# 1. using plot method on the crosstab dataframe
# 2. using plt.bar() and adjusting the postions manually and giving the inputs

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plotting the side-by-side bar chart
crosstab.plot(kind='bar', stacked=False, width=0.6, figsize=(10, 6))
# Customize the plot
plt.ylabel('No.of Vehicles')
plt.xlabel('No.of Gears')
plt.title('No.of Gears Vs No.of Carbs frequency distribution')
# Show the plot
plt.show()

# %%
categories = crosstab.index
bar_width = 0.2
positions_3 = np.arange(len(categories))
positions_4 = positions_3 + bar_width
positions_5 = positions_3 + 2*bar_width
height_3 = crosstab.loc[3].to_numpy().reshape(3)
height_4 = crosstab.loc[4].to_numpy().reshape(3)
height_5 = crosstab.loc[5].to_numpy().reshape(3)
plt.figure(figsize=(8,6))
plt.bar(x=positions_3,height=height_3,width=bar_width,label = 'cylinders = 4')
plt.bar(x=positions_4,height=height_4,width=bar_width,label= 'cylinders = 6')
plt.bar(x=positions_5,height= height_5,width=bar_width,label = 'cylinders = 8')
plt.legend()
# Add labels, title, and legend
plt.xlabel('No.of Gears')
plt.ylabel('No.of Vehicles')
plt.title('No.of Gears Vs No.of Carbs frequency distribution')
plt.xticks((positions_3 + positions_4 + positions_5) / 3,labels=['3','4','5'])  # Set x-axis ticks at the midpoint between A and B bars
plt.show()
